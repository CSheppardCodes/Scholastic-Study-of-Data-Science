# %% [markdown]
# <a href="https://colab.research.google.com/github/CSheppardCodes/Scholastic-Study-of-Data-Science/blob/main/basicDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
x = np.arange(1, 15)
y = np.array([1, 1.2, 1.4, 1.1, 1, 5.5, 6.1, 6.7, 6.4, 6, 6, 3, 3.2, 3.1])
df = pd.DataFrame({'x': x, 'y': y})

# %%
df
# Out:
#      x    y
# 0    1  1.0
# 1    2  1.2
# 2    3  1.4
# 3    4  1.1
# 4    5  1.0
# 5    6  5.5
# 6    7  6.1
# 7    8  6.7
# 8    9  6.4
# 9   10  6.0
# 10  11  6.0
# 11  12  3.0
# 12  13  3.2
# 13  14  3.1

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
X = df[['x']]

# %%
Y = df['y']

# %%
reg = DecisionTreeRegressor(max_depth=3)
reg.fit(X,Y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
from sklearn import tree

# %%
tree.plot_tree(reg, feature_names=X.columns)
# Out:
# [Text(0.5, 0.875, 'x <= 5.5\nsquared_error = 4.989\nsamples = 14\nvalue = 3.693'),
#  Text(0.25, 0.625, 'x <= 3.5\nsquared_error = 0.022\nsamples = 5\nvalue = 1.14'),
#  Text(0.125, 0.375, 'x <= 1.5\nsquared_error = 0.027\nsamples = 3\nvalue = 1.2'),
#  Text(0.0625, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.1875, 0.125, 'squared_error = 0.01\nsamples = 2\nvalue = 1.3'),
#  Text(0.375, 0.375, 'x <= 4.5\nsquared_error = 0.002\nsamples = 2\nvalue = 1.05'),
#  Text(0.3125, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 1.1'),
#  Text(0.4375, 0.125, 'squared_error = -0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.75, 0.625, 'x <= 11.5\nsquared_error = 2.117\nsamples = 9\nvalue = 5.111'),
#  Text(0.625, 0.375, 'x <= 6.5\nsquared_error = 0.138\nsamples = 6\nvalue = 6.117'),
#  Text(0.5625, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.5'),
#  Text(0.6875, 0.125, 'squared_error = 0.074\nsamples = 5\nvalue = 6.24'),
# ...

# %%
df.describe()
# Out:
#              x          y
# count  14.0000  14.000000
# mean    7.5000   3.692857
# std     4.1833   2.317978
# min     1.0000   1.000000
# 25%     4.2500   1.250000
# 50%     7.5000   3.150000
# 75%    10.7500   6.000000
# max    14.0000   6.700000

# %%
df['y'].describe()
# Out:
# count    14.000000
# mean      3.692857
# std       2.317978
# min       1.000000
# 25%       1.250000
# 50%       3.150000
# 75%       6.000000
# max       6.700000
# Name: y, dtype: float64

# %%
df['y'].var()
# Out:
# 5.3730219780219795
