# %% [markdown]
# <a href="https://colab.research.google.com/github/CSheppardCodes/Study-of-Data-Science/blob/main/Numpy%2BPandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={'state':['Ohio','Ohio','Ohio','Nevada',' Nevada','Nevada'], 'year':[2000,2001,2002,2001,2002,2003], 'pop':[1.5,1.7,3.6,2.4,2.9,3.2]}
frame=pd.DataFrame(data)

# %%
frame.describe()
# Out:
#               year       pop
# count     6.000000  6.000000
# mean   2001.500000  2.550000
# std       1.048809  0.836062
# min    2000.000000  1.500000
# 25%    2001.000000  1.875000
# 50%    2001.500000  2.650000
# 75%    2002.000000  3.125000
# max    2003.000000  3.600000

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   6 non-null      object
#  1   year    6 non-null      int64
#  2   pop     6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 272.0+ bytes

# %%
frame.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-bb0a26a5848f> in <cell line: 1>()
# ----> 1 frame.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
import numpy as np
df = pd.DataFrame(np.arange(1,16).reshape(5,3), index = list('abcde'), columns = list('xyz'))

# %%
df
# Out:
#     x   y   z
# a   1   2   3
# b   4   5   6
# c   7   8   9
# d  10  11  12
# e  13  14  15

# %%
df.loc['a','x']
# Out:
# 1

# %%
df.loc['a':'c','x':'y']#loc works with row names and column names
# Out:
#    x  y
# a  1  2
# b  4  5
# c  7  8

# %%
df1 = pd.DataFrame(np.random.randn(5,3))
df1
# Out:
#           0         1         2
# 0 -0.540320 -0.921650 -0.541261
# 1  0.705024 -0.084521  0.240513
# 2 -1.723076  0.265191 -0.039156
# 3  1.337812  0.385450  0.487365
# 4  0.517036  1.284047  0.270280

# %%
df1.loc[0:1,0:2]
# Out:
#           0         1         2
# 0 -0.923900  0.082589  0.448296
# 1  0.985192  0.683849  3.083925

# %%
df.iloc[0,1]
# Out:
# 2

# %%
df
# Out:
#     x   y   z
# a   1   2   3
# b   4   5   6
# c   7   8   9
# d  10  11  12
# e  13  14  15

# %%
df.iloc[0:,0:2]
# Out:
#     x   y
# a   1   2
# b   4   5
# c   7   8
# d  10  11
# e  13  14

# %%
type(df.iloc[0,:])#one row  is a series
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[:,:])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0,:]
# Out:
# x    1
# y    2
# z    3
# Name: a, dtype: int64

# %%
#lamba syntax
#double every element of column 1
my_data = (df.iloc[:,0])
my_data
# Out:
# a     1
# b     4
# c     7
# d    10
# e    13
# Name: x, dtype: int64

# %%
my_data.apply(lambda x: 2*x)
# Out:
# a     2
# b     8
# c    14
# d    20
# e    26
# Name: x, dtype: int64

# %%
#pandas.pydata.org

# %%
df_salary={'name':['Joe','Bill','Alice'], 'salary':[5000,6000,8000]}
frame1=pd.DataFrame(df_salary)

# %%
frame1=frame1.loc[:,'salary']*1.1
frame1
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-66-51c2b23f4394> in <cell line: 1>()
# ----> 1 frame1=frame1.loc[:,'salary']*1.1
#       2 frame1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1248
#    1249         # no multi-index, so validate all of the indexers
# -> 1250         tup = self._validate_tuple_indexer(tup)
#    1251
#    1252         # ugly hack for GH #836
#
# ...

# %%
frame1['salary']=
# Out:
# 0    5500.0
# 1    6600.0
# 2    8800.0
# Name: salary, dtype: float64

# %%
tyte = pd.read_csv("https://an-utd-python.s3-us-west-1.amazonaws.com/Salaries.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
salaries = pd.read_csv("/content/Salaries.csv", header = 0)

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
salaries.head()
# Out:
#    rank discipline  phd  service   sex  salary disipline
# 0  Prof          B   56       49  Male  186960         A
# 1  Prof          A   12        6  Male   93000         A
# 2  Prof          A   23       20  Male  110515         A
# 3  Prof          A   40       31  Male  131205         A
# 4  Prof          B   20       18  Male  104800         A

# %%
salaries[(salaries['discipline']=='A') & (salaries['salary']>1000)]#can use .isin
# Out:
#          rank discipline  phd  service     sex  salary disipline
# 1        Prof          A   12        6    Male   93000         A
# 2        Prof          A   23       20    Male  110515         A
# 3        Prof          A   40       31    Male  131205         A
# 5        Prof          A   20       20    Male  122400         A
# 6   AssocProf          A   20       17    Male   81285         A
# 7        Prof          A   18       18    Male  126300         A
# 8        Prof          A   29       19    Male   94350         A
# 9        Prof          A   51       51    Male   57800         A
# 18       Prof          A   19        7    Male  107300         A
# 19       Prof          A   29       27    Male  150500         A
# 21       Prof          A   33       30    Male  103106         A
# 22   AsstProf          A    4        2    Male   73000         A
# 23   AsstProf          A    2        0    Male   85000         A
# ...

# %%
salaries
# Out:
#          rank discipline  phd  service     sex  salary disipline
# 0        Prof          B   56       49    Male  186960         A
# 1        Prof          A   12        6    Male   93000         A
# 2        Prof          A   23       20    Male  110515         A
# 3        Prof          A   40       31    Male  131205         A
# 4        Prof          B   20       18    Male  104800         A
# ..        ...        ...  ...      ...     ...     ...       ...
# 73       Prof          B   18       10  Female  105450         A
# 74  AssocProf          B   19        6  Female  104542         A
# 75       Prof          B   17       17  Female  124312         A
# 76       Prof          A   28       14  Female  109954         A
# 77       Prof          A   23       15  Female  109646         A
#
# [78 rows x 7 columns]

# %%
salaries['rank'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: rank, Length: 78, dtype: bool

# %%
salaries.isna().sum()#check for null values
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# disipline     0
# dtype: int64

# %%
salaries.mean()
# Out:
# <ipython-input-25-181e3dbdd7ec>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
salaries.sort_values(by='salary')#sort
# Out:
#          rank discipline  phd  service     sex  salary disipline
# 9        Prof          A   51       51    Male   57800         A
# 54  AssocProf          A   25       22  Female   62884         A
# 66   AsstProf          A    7        6  Female   63100         A
# 71  AssocProf          B   12        9  Female   71065         A
# 57   AsstProf          A    3        1  Female   72500         A
# ..        ...        ...  ...      ...     ...     ...       ...
# 31       Prof          B   22       21    Male  155750         A
# 27       Prof          A   45       43    Male  155865         A
# 72       Prof          B   24       15  Female  161101         A
# 13       Prof          B   35       33    Male  162200         A
# 0        Prof          B   56       49    Male  186960         A
#
# [78 rows x 7 columns]

# %%
salaries.sort_values(by=['salary','service'], ascending = False)#sort
# Out:
#          rank discipline  phd  service     sex  salary disipline
# 0        Prof          B   56       49    Male  186960         A
# 13       Prof          B   35       33    Male  162200         A
# 72       Prof          B   24       15  Female  161101         A
# 27       Prof          A   45       43    Male  155865         A
# 31       Prof          B   22       21    Male  155750         A
# ..        ...        ...  ...      ...     ...     ...       ...
# 55   AsstProf          A    2        0  Female   72500         A
# 71  AssocProf          B   12        9  Female   71065         A
# 66   AsstProf          A    7        6  Female   63100         A
# 54  AssocProf          A   25       22  Female   62884         A
# 9        Prof          A   51       51    Male   57800         A
#
# [78 rows x 7 columns]

# %%
meansale = salaries['salary'].mean()
meansale
# Out:
# 108023.78205128205

# %%
salaries[(salaries['salary'] > salaries['salary'].mean())]
#salaries[(salaries['discipline']=='A') & (salaries['salary']>1000)]#can use .isin
# Out:
#          rank discipline  phd  service     sex  salary disipline
# 0        Prof          B   56       49    Male  186960         A
# 2        Prof          A   23       20    Male  110515         A
# 3        Prof          A   40       31    Male  131205         A
# 5        Prof          A   20       20    Male  122400         A
# 7        Prof          A   18       18    Male  126300         A
# 10       Prof          B   39       33    Male  128250         A
# 11       Prof          B   23       23    Male  134778         A
# 13       Prof          B   35       33    Male  162200         A
# 14       Prof          B   25       19    Male  153750         A
# 15       Prof          B   17        3    Male  150480         A
# 19       Prof          A   29       27    Male  150500         A
# 26       Prof          A   38       19    Male  148750         A
# 27       Prof          A   45       43    Male  155865         A
# ...

# %%
salaries.mean()
# Out:
# <ipython-input-39-181e3dbdd7ec>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64
